# %% [markdown]
# **salad detector with TensorFlow Lite Model Maker**

# %% [markdown]
# 1. train a custom object detection model using TFLite Model Maker.
#
#
# 2. deploy a TFLite object detection model using TFLite Task Library.

# %%
# Install TensorFlow (compatible version for tflite-model-maker)
# !pip install tensorflow==2.11.0

# Install pycocotools
# !pip install pycocotools

# Install tflite-support
# !pip install tflite-support==0.4.3

# Install tflite-model-maker (specific version)
# !pip install tflite-model-maker==0.4.3 --use-deprecated=legacy-resolver

# %%
# !pip install scann==1.3.4

# %%
# !pip install tflite-model-maker==0.4.3 --no-deps

# %%
# !pip install tensorflowjs

# %%
# !pip install tflite-support

# %%
# !pip install protobuf==3.20.3

# %%
# %env PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION=python

# %%
import numpy as np
import os

from tflite_model_maker.config import ExportFormat
from tflite_model_maker import model_spec
from tflite_model_maker import object_detector

import tensorflow as tf
assert tf.__version__.startswith('2')

tf.get_logger().setLevel('ERROR')
from absl import logging
logging.set_verbosity(logging.ERROR)
